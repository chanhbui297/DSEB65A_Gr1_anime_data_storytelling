# %% [markdown]
# ## **I. Introduction**
# **1. Narrative Context**
#
# In the previous stage, we took on the role of a Producer seeking the formula behind high-scoring anime. However, our first obstacle was immediate and unavoidable: the Raw Dataset was in poor condition. It contained missing values, unstructured text, inconsistent formats, and fragmented categories — making meaningful analysis impossible.
#
# This notebook presents the next stage of the workflow: **the transformation**.
# After applying a complete Data Processing Pipeline to clean, standardize, and engineer features, we now visualize the impact of that transformation. This notebook serves as evidence of how structured data enables structured insights.
#
# **2. Objective of This Analysis**
#
# The focus of this notebook is **Comparative Analysis**.
# For every major feature, we address two key questions:
#
# 1. **The Transformation Insight** — How did the feature evolve from **Raw** to **Processed**?
# This shows why Data Preparation is not optional but foundational.
#
# 2. **The Business Insight** — Once the data is clean, what does it reveal about the drivers of **high Score**?
#
# In short, the purpose is not only to clean the data, but to demonstrate how cleaning transforms noise into clarity and reveals the signals that matter.
#
# **3. Analytical Roadmap**
#
# This transformation is explored through four structured themes:
#
# 1. **The Foundation – Target Variable (Score)**
#    Revealing the true distribution and statistical behavior of the target metric.
#
# 2. **Theme A – Market Factors**
#    Understanding how Media Type (TV, Movie, OVA…) and Source Material (Manga, Original, Game…) influence performance.
#
# 3. **Theme B – Creative Factors**
#    Unpacking Genres, Producers, and Studios to identify collaboration patterns, specialization strengths, and creative drivers.
#
# 4. **Theme C – Release Strategy**
#    Converting unstructured Aired dates, Duration formats, and Episode structures into analyzable fields to uncover timing and format advantages.
#
# **4. Deep Business Insights → Strategic Recommendations**
#
# At the end of this notebook, we consolidate the strongest patterns discovered across all themes to form **Strategic Recommendations** for creating or selecting high-scoring anime.
# These insights connect data evidence to real-world decision-making — guiding choices about **content strategy**, **production planning**, **studio partnerships**, and **release timing**.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import pandas as pd
import numpy as np
import joblib
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
path_raw = r'..\data\raw\anime-dataset-2023.csv'
df_anime_dataset_2023 = pd.read_csv(path_raw)

path = r'..\data\processed\prepared_data.csv'
df_anime_dataset_2023_prep= pd.read_csv(path)

# %% [markdown]
# ## **II. Target Variable: Score**
#
# ### **1. Issue Overview**
#
#
# ### **2. Solution**
#
#
# ### **3. Visual Evidence: Misleading (Raw) vs. Correct (Clean) Insights**

# %%
import plotly.express as px
from plotly.subplots import make_subplots
import pandas as pd

# --- Prepare Data ---
df_raw_viz = df_anime_dataset_2023.copy()
df_raw_viz['Score'] = df_raw_viz['Score'].astype(str)

unknown_count = df_raw_viz[df_raw_viz['Score']=='UNKNOWN'].shape[0]

score_counts = df_raw_viz['Score'].value_counts().reset_index()
score_counts.columns = ['Score','Frequency']
score_counts['Color'] = score_counts['Score'].apply(lambda x: 'Misleading (Unknown)' if x=='UNKNOWN' else 'Valid Score')
top_scores = score_counts.head(15)

# --- Create Subplots ---
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("<b>Broken Histogram: Raw Score<b>", "<b>Top 15 Scores (Unknown Highlighted)<b>"),
    horizontal_spacing=0.15  # khoảng cách giữa 2 chart
)

# --- Chart 1: Histogram ---
hist_fig = px.histogram(df_raw_viz, x='Score', color_discrete_sequence=["#7814cf"])
for trace in hist_fig.data:
    fig.add_trace(trace, row=1, col=1)

fig.add_annotation(
    x='UNKNOWN', y=unknown_count,
    text=f"<b>UNKNOWN: {unknown_count}</b><br>(Dominates the data)",
    showarrow=True, arrowhead=2, ax=0, ay=-40,
    font=dict(color="#C3122F", size=14), arrowcolor="#C3122F",
    row=1, col=1
)

fig.update_xaxes(type='category', row=1, col=1, showticklabels=False)
fig.update_yaxes(title_text="Count", row=1, col=1)

# --- Chart 2: Horizontal Bar ---
bar_fig = px.bar(
    top_scores,
    x='Frequency',
    y='Score',
    orientation='h',
    color='Color',
    color_discrete_map={'Misleading (Unknown)': '#C3122F', 'Valid Score': '#95a5a6'},
    text='Frequency'
)
for trace in bar_fig.data:
    fig.add_trace(trace, row=1, col=2)

# --- Critical Settings to keep text outside ---
fig.update_traces(textposition='outside', textfont=dict(size=14, color='black'), row=1, col=2)

fig.update_yaxes(categoryorder='total ascending', row=1, col=2, showgrid=False, showline=False)
fig.update_xaxes(showticklabels=False, showgrid=False, zeroline=False, showline=False,
                 row=1, col=2, automargin=True, range=[0, max(top_scores['Frequency'])*1.3])

# --- Layout chung ---
fig.update_layout(
    template='plotly_white',
    showlegend=False,
    height=500,
    width=1300,  # tăng chiều rộng tổng thể
    margin=dict(l=60, r=150, t=80, b=50),
    title_text="<b>Raw Score Analysis: Broken vs Unknown Dominance</b>"
)

fig.show()


# 1. Drop NaN just for plotting (Storytelling purpose: Show the valid distribution)
# In prepared_data.csv, Score is already float, but might have NaNs. 
# We visualize the AVAILABLE valid scores.
valid_scores = df_cleaned['Score'].dropna()

# 2. Calculate Statistics for Annotation
mean_score = valid_scores.mean()
median_score = valid_scores.median()

# 3. Plot Histogram
fig = px.histogram(
    x=valid_scores,
    nbins=40, # Granular bins
    title='<b>True Anime Score Distribution (Cleaned)</b><br><i>(Gaussian-like distribution after removing noise)</i>',
    color_discrete_sequence=["#7C2EC1"], # Professional Blue
    opacity=0.8
)

# 4. Add Mean Line (Vertical Line)
fig.add_vline(
    x=mean_score, 
    line_width=3, 
    line_dash="dash", 
    line_color="#C3122F",
    annotation_text=f"Mean: {mean_score:.2f}", 
    annotation_position="top right"
)

# 5. Declutter
fig.update_layout(
    template='plotly_white',
    xaxis_title="Score (0-10)",
    yaxis_title="Frequency",
    bargap=0.1,
    height=500
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 75
#      69 fig.show()
#      72 # 1. Drop NaN just for plotting (Storytelling purpose: Show the valid distribution)
#      73 # In prepared_data.csv, Score is already float, but might have NaNs.
#      74 # We visualize the AVAILABLE valid scores.
# ---> 75 valid_scores = df_cleaned['Score'].dropna()
#      77 # 2. Calculate Statistics for Annotation
#      78 mean_score = valid_scores.mean()
#
# NameError: name 'df_cleaned' is not defined

# %% [markdown]
# ##### **The Transformation Insight:**
#
# **The Misleading View:** The raw data suggested that a large portion of anime had undefined or unknown scores, obscuring the true distribution and making it impossible to assess typical performance.
#
# **The Truth:** The clean data reveals a roughly Gaussian distribution, with most scores clustering around 6.38, and extreme low or high scores being rare.
#
# **The Strategic Value:** Instead of noise, we now have a reliable numeric feature to analyze how Score varies across Types, Sources, and other factors, enabling accurate business insights.

# %% [markdown]
# ## **III. Theme A — Market Factors (Type & Source)**
#
# ### **1. Issue Overview**
#
#
# ### **2. Solution**
#
#
# ### **3. Visual Evidence: Misleading (Raw) vs. Correct (Clean) Insights**

# %% [markdown]
# ##### **The Transformation Insight:**
# Áp dụng công thức
#
# The Misleading View: The raw data suggested that [Misleading Insight] (or obscured the pattern due to [Specific Noise]).
#
# The Truth: The clean data corrects this by revealing that [Correct Insight/Real Pattern].
#
# The Strategic Value: Instead of noise, we now have a reliable feature to analyze [How this feature impacts Score].

# %% [markdown]
# ### **4. Business Insights**

# %% [markdown]
# #### **A. [Tên]**
# **Question**:

# %% [markdown]
# **Insight:**
#
# **Business Takeaway:**

# %% [markdown]
# ## **IV. Theme B — Creative & Production Factors (Genres, Producers, Studios)**
#
# ### **1. Issue Overview**
#
#
# ### **2. Solution**
#
#
# ### **3. Visual Evidence: Misleading (Raw) vs. Correct (Clean) Insights**

# %% [markdown]
# ##### **The Transformation Insight:**
#
# **Before**:
#
# **After**

# %% [markdown]
# ### **4. Business Insights**

# %% [markdown]
# #### **A. Producer Count Analysis**
# **Question**:

# %% [markdown]
# **Insight:**
#
# **Business Takeaway:**

# %% [markdown]
# ## **V. Theme C — Release Strategy (Aired, Episodes, Duration)**
#
# ### **1. Issue Overview**
#
#
# #### **a. Inconsistent Aired Dates**
# The *Aired* field contains heterogeneous and irregular date formats (e.g., ranges, partial dates, or text-based strings).
# Because of this inconsistency, the dataset **cannot support any temporal or seasonal analysis**, such as evaluating how *Score* varies by **year**, **quarter**, or **release season**.
#
# #### **b. Unstructured Duration Values**
# The *Duration* attribute is stored as free-form text (e.g., "24 min per ep", "1 hr 30 min", "Unknown").
# This prevents the separation of **TV shorts**, **standard TV episodes**, **movies**, and **specials** into meaningful analytical categories.
# As a result, it becomes **impossible to assess the relationship between Duration and Score**, or to compare performance across runtime formats.
#
#
#
# ### **2. Solution**
#
#
# #### **a. Standardizing Aired Dates**
# To resolve the inconsistencies in the *Aired* field, the raw date strings were:
# - parsed into standardized `datetime` objects,
# - decomposed into analytical components such as **Year**, **Month**, **Quarter**, and **Season**, and mapped to canonical anime release seasons (Winter, Spring, Summer, Fall).
#
# This transformation enables reliable temporal analysis and allows us to examine how **Score varies by year, seasonality, and release timing**.
#
# #### **b. Structuring Duration into Numeric Format**
# The *Duration* values were cleaned by:
# - Extracting numeric runtime from textual strings,
# - Converting all formats into a unified measure (minutes per episode), and categorizing them into meaningful groups such as
#   **TV Short**, **Standard TV (24 min)**, **Long-Form Special**, and **Movie Runtime**.
#
# This standardization makes it possible to study **how different runtime formats relate to Score** and compare performance across media types in a consistent manner.
#
#
#
# ### **3. Visual Evidence: Misleading (Raw) vs. Correct (Clean) Insights**
# #### **a. Raw vs Clean: Number of Anime released per month**

# %%
# --- Raw Data (giữ nguyên code) ---
df_raw_viz['Extracted Month'] = df_raw_viz['Aired'].str.extract(
    r'(\bJan|\bFeb|\bMar|\bApr|\bMay|\bJun|\bJul|\bAug|\bSep|\bOct|\bNov|\bDec)',
    expand=False
)
raw_counts = df_raw_viz['Extracted Month'].value_counts().sort_index()  # giữ sort_index như cũ

# --- Clean Data (giữ nguyên code) ---
clean_counts = df_anime_dataset_2023_prep['Aired Month'].value_counts().sort_index()
month_map = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
clean_month_names = [month_map[m] for m in clean_counts.index]

# --- Create 1 row x 2 cols subplot ---
# horizontal_spacing: khoảng cách giữa 2 subplot (0~1)
fig = make_subplots(
    rows=1, cols=2,
    horizontal_spacing=0.3,  # giảm khoảng cách nếu muốn 2 biểu đồ gần nhau hơn
    subplot_titles=("","")     # không dùng subplot title mặc định
)

# --- Add Raw Data Bar ---
fig.add_trace(go.Bar(
    x=raw_counts.index,
    y=raw_counts.values,
    marker_color="#D3D3D3",
    marker_line_width=1,
    marker_line_color="white",
    text=raw_counts.values,
    texttemplate="%{text:,}",
    textposition="outside",
    showlegend=False,
    hovertemplate="<b>Month:</b> %{x}<br><b>Count:</b> %{y:,}<extra></extra>",
    name="Raw Data"  # để có thể hiển thị legend nếu muốn
), row=1, col=1)

# --- Add Clean Data Bar ---
fig.add_trace(go.Bar(
    x=clean_month_names,
    y=clean_counts.values,
    marker_color="#ea568c",
    marker_line_width=1,
    marker_line_color="white",
    text=clean_counts.values,
    texttemplate="%{text:,}",
    textposition="outside",
    hovertemplate="<b>Month:</b> %{x}<br><b>Count:</b> %{y:,}<extra></extra>",
    name="Clean Data",
    showlegend=False

), row=1, col=2)

# --- Layout giữ nguyên style, figure size, margin ---
fig.update_layout(
    template="plotly_white",
    height=450,  # chiều cao figure
    width=1200,  # chiều rộng figure
    margin=dict(l=40, r=40, t=100, b=60),
    font=dict(family="Tahoma"),
    hovermode="x unified",
    # bargap: khoảng cách giữa các bar trong cùng 1 subplot
    bargap=0.7
)

# --- X & Y axis: giữ nguyên font, màu, tick, label ---
# Subplot 1 (Raw)
fig.update_xaxes(
    title="",
    tickangle=0,
    showgrid=False,
    tickfont=dict(family="Tahoma", size=13, color="#C3122F", weight="bold"),
    row=1, col=1
)
fig.update_yaxes(
    title="",
    showticklabels=False,
    showgrid=False,
    row=1, col=1
)

# Subplot 2 (Clean)
fig.update_xaxes(
    title="",
    tickangle=0,
    showgrid=False,
    tickfont=dict(family="Tahoma", size=13, color="black", weight="bold"),
    row=1, col=2
)
fig.update_yaxes(
    title="",
    showticklabels=False,
    showgrid=False,
    row=1, col=2
)

# --- Adjust bar width & text font cho tất cả trace ---
# width: tỷ lệ chiều rộng của bar (0~1)
fig.update_traces(width=0.7, textfont=dict(size=13))

# --- Thêm annotation cho title/subtitle sát lề ---
fig.add_annotation(
    text="<b>Number of Anime Released per Month</b><br>"
         "<span style='color:#555555; font-size:14px'>"
         "(Raw Data)</span>",
    x=-0.025, y=1.25, xref='paper', yref='paper',
    showarrow=False, align="left",
    font=dict(family="Tahoma", size=18, color="black")
)
fig.add_annotation(
    text="<b>Number of Anime Released per Month</b><br>"
         "<span style='color:#555555; font-size:14px'>"
         "(Cleaned Data)</span>",
    x=0.97, y=1.25, xref='paper', yref='paper',
    showarrow=False, align="left",
    font=dict(family="Tahoma", size=18, color="black")
)

# --- Optional: thêm legend nếu muốn hiển thị tên trace ---
fig.update_layout(
    showlegend=True,
    legend=dict(
        x=0.5, y=1.0,       # vị trí legend
        xanchor="center",
        yanchor="bottom",
        orientation="h",
        font=dict(size=12)
    )
)
fig.update_traces(width=0.8)  
fig.update_layout(
    height=500,  # tăng chiều cao figure để subplot lớn hơn
    width=1400   # tăng chiều rộng figure
)



fig.show()

# %% [markdown]
# #### **b. Raw vs Clean: Average score of Anime released per year**

# %%
# Prepare data: Average Score by Release Year (Cleaned)
score_by_year = df_anime_dataset_2023_prep.groupby('Aired Year')['Score'].mean().dropna()
x_years = score_by_year.index
y_scores = score_by_year.values

# Create Line Chart — Average Score by Release Year (Cleaned)
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x_years,
    y=y_scores,
    mode='lines+markers',
    line=dict(color='#ea568c', width=3),
    marker=dict(size=7, color='#ea568c'),
    name='Dữ liệu sạch',
    showlegend=False,
    text=[f"{score:.2f}" for score in y_scores],
    hovertemplate='Year=%{x}<br>Average Score=%{y:.2f}<extra></extra>'
))

fig.update_layout(
    template='plotly_white',
    font=dict(family="Tahoma"),
    margin=dict(l=40, r=40, t=100, b=60),
    title=dict(
        text="<b>Clean Data Reveals True Score Trend</b><br><span style='color:#555555; font-size:14px'>(Average Score by Release Year)</span>",
        x=0.02
    ),
    hovermode="x unified",
    xaxis=dict(
        title="Year",
        showgrid=False,
        tickformat="d",
        nticks=15
    ),
    yaxis=dict(
        title="Average Score",
        showgrid=False,
        tickformat=".2f"
    ),
    legend=dict(
        x=1.02, y=0.98, xanchor='left', yanchor='top', bgcolor='rgba(0,0,0,0)'
    )
)

fig.show()

# %%
import plotly.graph_objects as go

# --- Prepare Data ---
x_years_raw = score_by_year_raw.index
y_scores_raw = score_by_year_raw.values

# --- Create Line Chart ---
fig = go.Figure()

# Add Raw Data Line
fig.add_trace(go.Scatter(
    x=x_years_raw,
    y=y_scores_raw,
    mode='lines+markers',
    line=dict(color='#C3122F', width=3),  # Red for raw data
    marker=dict(size=7, color='#C3122F'),
    name='Dữ liệu thô (có outlier)',
    hovertemplate='Year=%{x}<br>Average Score=%{y:.2f}<extra></extra>'
))

# --- Layout Settings ---
fig.update_layout(
    template='plotly_white',
    font=dict(family="Tahoma"),
    margin=dict(l=40, r=40, t=100, b=60),
    title=dict(
        text="<b>Raw Data: Average Score by Release Year</b><br>"
             "<span style='color:#555555; font-size:14px'>(Line Chart — Raw Data)</span>",
        x=0.02
    ),
    hovermode="x unified",
    xaxis=dict(
        title="Year",
        showgrid=False,
        tickformat="d",
        nticks=15
    ),
    yaxis=dict(
        title="Average Score",
        showgrid=False,
        tickformat=".2f"
    ),
    legend=dict(
        x=1.02, y=0.98, xanchor='left', yanchor='top', bgcolor='rgba(0,0,0,0)'
    )
)

# --- Export Settings ---
fig.write_image("raw_data_average_score.png", scale=3, width=1000, height=550)

# Show the figure
fig.show()

# %%
import plotly.graph_objects as go

# --- Prepare Data ---
# Ensure 'Aired Year' exists in df_raw_viz
if 'Aired Year' not in df_raw_viz.columns:
    df_raw_viz['Aired Year'] = pd.to_datetime(df_raw_viz['Aired'], errors='coerce').dt.year

# Calculate average score by year for raw data
df_raw_viz['Score'] = pd.to_numeric(df_raw_viz['Score'], errors='coerce')  # Convert 'Score' to numeric, setting non-numeric values to NaN
score_by_year = (
    df_raw_viz.groupby('Aired Year')['Score']
    .mean()
    .dropna()  # Drop rows where the mean could not be calculated due to NaN
)
x_years_raw = score_by_year.index
y_scores_raw = score_by_year.values

# Calculate average score by year for clean data
score_by_year_clean = df_anime_dataset_2023_prep.groupby('Aired Year')['Score'].mean()
x_years_clean = score_by_year_clean.index
y_scores_clean = score_by_year_clean.values

# --- Create Line Chart ---
fig = go.Figure()

# Add Raw Data Line
fig.add_trace(go.Scatter(
    x=x_years_raw,
    y=y_scores_raw,
    mode='lines+markers',
    line=dict(color='#C3122F', width=2, dash='dash'),
    marker=dict(size=6, color='#C3122F'),
    name='Raw Data',
    hovertemplate='Year=%{x}<br>Average Score=%{y:.2f}<extra></extra>'
))

# Add Clean Data Line
fig.add_trace(go.Scatter(
    x=x_years_clean,
    y=y_scores_clean,
    mode='lines+markers',
    line=dict(color='#ea568c', width=3),
    marker=dict(size=7, color='#ea568c'),
    name='Clean Data',
    hovertemplate='Year=%{x}<br>Average Score=%{y:.2f}<extra></extra>'
))

# --- Layout Settings ---
fig.update_layout(
    template='plotly_white',
    font=dict(family="Tahoma"),
    margin=dict(l=40, r=40, t=100, b=60),
    title=dict(
        text="<b>Raw vs Clean: Average Score of Anime Released per Year</b><br>"
             "<span style='color:#555555; font-size:14px'>(Line Chart — Raw vs Clean Data)</span>",
        x=0.02
    ),
    hovermode="x unified",
    xaxis=dict(
        title="Year",
        showgrid=False,
        tickformat="d",
        nticks=15
    ),
    yaxis=dict(
        title="Average Score",
        showgrid=False,
        showticklabels=False,
        tickformat=".2f"
    ),
    legend=dict(
        x=1.02, y=0.98, xanchor='left', yanchor='top', bgcolor='rgba(0,0,0,0)'
    )
)

# Show the figure
fig.show()

# %% [markdown]
# ### **The Transformation Insight:**
#
# #### **1. Average Score per Year**
#
# ##### **Before Cleaning (Raw Data)**
# **Observations:**
# - The raw dataset contains many undefined or inconsistent values, leading to the presence of outliers.
# - Early years (1917–1940) show significantly lower average scores, likely due to limited anime production and lower animation quality during that period.
# - From the 2000s onward, the average score gradually increases, reflecting advancements in production quality and the expansion of the anime industry.
#
# **Limitations:**
# - Raw data is unreliable due to missing values, inconsistent formatting, and noise, which distort the true score distribution.
#
# ##### **After Cleaning (Cleaned Data)**
# **Observations:**
# - After cleaning, the trend becomes much clearer: average scores increase steadily across the years.
# - Scores rise significantly starting from the early 2000s and peak around 2020–2023.
# - Recent years consistently achieve higher scores, indicating improvements in animation technology and greater investment in content quality.
#
# **Strategic Value:**
# - Studios can use these trends to understand changes in audience expectations and adjust production strategies to maintain high-quality output.
#
#
# #### **2. Released Anime per Month**
#
# ##### **Before Cleaning (Raw Data)**
# **Observations:**
# - The raw data shows an uneven distribution of anime releases across months.
# - Months such as **April (Apr)** and **October (Oct)** appear to have higher release counts, but the data is noisy and inconsistent.
#
# **Limitations:**
# - The presence of malformed date values and unclear formatting reduces the reliability of the raw monthly distribution.
#
#
# ##### **After Cleaning (Cleaned Data)**
# **Observations:**
# - After cleanup, the distribution becomes more accurate and meaningful.
# - **April (Apr)** and **October (Oct)** stand out as the peak release months.
# - Other months such as **January (Jan)** and **July (Jul)** also show notable release activity, reflecting typical seasonal release cycles in the anime industry.
#
# **Strategic Value:**
# - Studios can optimize release schedules by targeting months with historically high audience engagement, increasing the visibility and success of new titles.
#
#
# #### **3. Combined Insights**
#
# ##### **Temporal Trends**
# - The average score of anime has steadily increased, especially from the year 2000 onward.
# - Specific months — **April, October, January, and July** — consistently serve as popular release periods within the industry.
#
# ##### **Strategic Recommendations**
# - **Optimize Release Timing:**
#   Studios should prioritize releasing new anime during high-traffic months to maximize audience reach and potential success.
#
# - **Focus on Production Quality:**
#   Investing in animation quality, storytelling, and production resources is essential to maintain the upward trend in audience ratings.

# %% [markdown]
# #### **b. Raw vs Clean: Duration and Score**

# %%
import plotly.express as px


fig = px.scatter(
    df_raw_viz,
    x='Aired',
    y='Score',
    color_discrete_sequence=["#C3122F"],  
)

fig.update_traces(marker=dict(size=6, opacity=0.7))

fig.update_layout(
    template='plotly_white',
    font=dict(family="Tahoma"),
    height=520,
    

    title=dict(
        text=(
            "<b>Raw Aired Dates Do Not Explain Score</b><br>"
            "<span style='color:#555555; font-size:14px'>(Scatter Plot — Score vs Aired String)</span>"
        ),
        x=0.02
    ),
    
    margin=dict(l=40, r=40, t=110, b=60),
    hovermode="x unified",

    xaxis=dict(
        title='Raw Aired (String)',
        showgrid=False,
        tickangle=0,
        nticks=7      # giảm tick để hạn chế chữ bị nát
    ),
    yaxis=dict(
        title='Score',
        showgrid=True
    ),
)

fig.show()

# %%
import plotly.express as px

# --- Scatter Plot: Score vs Duration (String) ---
fig = px.scatter(
    df_raw_viz,
    x='Duration',
    y='Score',
    color_discrete_sequence=["#C3122F"],  # RAW = red
)

# --- Layout & Style Adjustments (Group Requirements) ---
fig.update_traces(marker=dict(size=6, opacity=0.7))

fig.update_layout(
    template='plotly_white',
    font=dict(family="Tahoma"),
    height=520,
    
    title=dict(
        text=(
            "<b>Raw Duration Fails to Explain Score</b><br>"
            "<span style='color:#555555; font-size:14px'>(Scatter Plot — Score vs Duration String)</span>"
        ),
        x=0.02
    ),
    
    margin=dict(l=40, r=40, t=110, b=60),
    hovermode="x unified",
    
    xaxis=dict(
        title='Duration (String)',
        showgrid=False,
        tickangle=0,
        nticks=8,         
    ),
    yaxis=dict(
        title='Score',
        showgrid=True
    )
)

fig.show()

# %% [markdown]
# ##### **The Transformation Insight:**
#
# **Before**:
#
# **After**:

# %% [markdown]
# ## **IV. Theme B — Creative & Production Factors (Genres, Producers, Studios)**
#
# ### **1. Issue Overview**
#
#
# ### **2. Solution**
#
#
# ### **3. Visual Evidence: Misleading (Raw) vs. Correct (Clean) Insights**

# %% [markdown]
# ##### **The Transformation Insight:**
#
# **Before**:
#
# **After**

# %% [markdown]
# ### **4. Business Insights**

# %% [markdown]
# #### **A.**
# **Question**:

# %% [markdown]
# **Insight:**
#
# **Business Takeaway:**

# %% [markdown]
# ## **VI. Deep Business Insights & Strategic Recommendations**
#
# **1. Key Patterns Across All Themes**
#
# **2. Strategic Recommendations**
